# %%
#https://play.google.com/store/apps/details?id=camera.timestamp.gpsmap.photo.gpscamera
#this script creates a text file for GPS data captured from above given app
import os
import re
import cv2
import pytesseract
from PIL import Image, ImageEnhance

# === Config ===
image_folder = r"G:\Group_2_Road_Defect_Analysis\Prediction_Output"
label_folder = r"G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels"
output_folder = r"G:\Group_2_Road_Defect_Analysis\Prediction_Output\gps_text"
os.makedirs(output_folder, exist_ok=True)

pytesseract.pytesseract.tesseract_cmd = r"C:\Users\HP\tesseract.exe"
class_names = ['edge line', 'Potholes', 'crack', 'lane divider', 'objects', 'zebra crossing']

# === Helper Functions ===

def extract_text(image_path):
    img = Image.open(image_path).convert("L")  # Grayscale
    img = img.resize((img.width * 2, img.height * 2))  # Enlarge
    img = ImageEnhance.Contrast(img).enhance(2)  # Increase contrast
    text = pytesseract.image_to_string(img)
    return text

def parse_location_and_gps(text):
    location = None
    lat, lon = None, None

    # === Location pattern: 'Link Road Ahmednagar Maharashtra'
    loc_match = re.search(r'(Link Road [A-Za-z\s]+Maharashtra)', text)
    if loc_match:
        location = loc_match.group(1).strip()

    # === Decimal degrees pattern: Lat: xx.xxxx Long: xx.xxxx OR with pipe |
    match_dec = re.search(r'Lat[: ]+([\d.]+)\s*[|]?\s*Long[: ]+([\d.]+)', text)
    if match_dec:
        lat = float(match_dec.group(1))
        lon = float(match_dec.group(2))

    # === Optional fallback: DMS format (not needed for your current OCR but kept just in case)
    if not lat or not lon:
        match_dms = re.search(
            r'(\d{1,2})°\s*(\d{1,2})[′\'’]?\s*(\d{1,2})?[″"\s]*[Nn],?\s*(\d{1,3})°\s*(\d{1,2})[′\'’]?\s*(\d{1,2})?[″"\s]*[Ee]',
            text
        )
        if match_dms:
            d1, m1, s1 = int(match_dms.group(1)), int(match_dms.group(2)), int(match_dms.group(3) or 0)
            d2, m2, s2 = int(match_dms.group(4)), int(match_dms.group(5)), int(match_dms.group(6) or 0)
            lat = d1 + m1 / 60 + s1 / 3600
            lon = d2 + m2 / 60 + s2 / 3600

    return location, lat, lon

def read_labels(label_path):
    if not os.path.exists(label_path):
        return []
    with open(label_path, 'r') as f:
        lines = f.readlines()
        return list(set(class_names[int(line.split()[0])] for line in lines if line.strip()))

# === Main Processing ===

for file in os.listdir(image_folder):
    if not file.lower().endswith('.jpg'):
        continue

    image_path = os.path.join(image_folder, file)
    label_path = os.path.join(label_folder, file.replace('.jpg', '.txt'))
    output_txt_path = os.path.join(output_folder, file.replace('.jpg', '.txt'))

    ocr_text = extract_text(image_path)
    location, lat, lon = parse_location_and_gps(ocr_text)
    defects = read_labels(label_path)

    with open(output_txt_path, 'w', encoding='utf-8') as out:
        out.write(f"Frame: {file}\n")
        out.write(f"Location: {location or 'Unknown'}\n")
        out.write(f"Latitude: {lat if lat else 'NA'}\n")
        out.write(f"Longitude: {lon if lon else 'NA'}\n")
        out.write(f"Defects: {', '.join(defects) if defects else 'None'}\n")

print("✅ All frame data saved as .txt files.")
# Out:
# ✅ All frame data saved as .txt files.

# %%
#this code creates a csv file for tha GPS data we have fetched in text file

import os
import csv

# === Configuration ===
gps_txt_dir = r"G:\Group_2_Road_Defect_Analysis\Prediction_Output\gps_text"
yolo_labels_dir = r"G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels"
output_csv_path = r"G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\defect_summary.csv"

class_names = ['edge line', 'Potholes', 'crack', 'lane divider', 'objects', 'zebra crossing']

# === Functions ===

def extract_gps_info(filepath):
    lat, lon, location = None, None, None
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line.startswith("Latitude:"):
                value = line.split("Latitude:")[1].strip()
                lat = float(value) if value.replace('.', '', 1).isdigit() else None
            elif line.startswith("Longitude:"):
                value = line.split("Longitude:")[1].strip()
                lon = float(value) if value.replace('.', '', 1).isdigit() else None
            elif line.startswith("Location:"):
                location = line.split("Location:")[1].strip()
    return location, lat, lon

def extract_labels(yolo_file):
    if not os.path.exists(yolo_file):
        print(f"⚠️ Label file not found: {yolo_file}")
        return []

    class_ids = []
    with open(yolo_file, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f:
            parts = line.strip().split()
            if parts and parts[0].isdigit():
                class_ids.append(int(parts[0]))
            else:
                print(f"⚠️ Skipping invalid label line: {line.strip()} in {yolo_file}")
    return [class_names[i] for i in class_ids if i < len(class_names)]

# === Main Processing ===
data = []
all_gps_files = os.listdir(gps_txt_dir)
print(f"📝 Found {len(all_gps_files)} GPS text files.")

for fname in all_gps_files:
    if not fname.endswith('.txt'):
        continue

    frame_name = os.path.splitext(fname)[0] + '.jpg'
    txt_path = os.path.join(gps_txt_dir, fname)
    yolo_label_path = os.path.join(yolo_labels_dir, os.path.splitext(fname)[0] + '.txt')

    location, lat, lon = extract_gps_info(txt_path)
    labels = extract_labels(yolo_label_path)

    print(f"📂 Frame: {frame_name} | Location: {location} | Lat: {lat}, Lon: {lon} | Labels: {labels}")

    if location and lat is not None and lon is not None and labels:
        unique_labels = sorted(set(labels))
        defect_str = ', '.join(unique_labels)
        count = len(labels)

        data.append({
            'frame': frame_name,
            'location': location,
            'latitude': lat,
            'longitude': lon,
            'defects': defect_str,
            'count': count
        })
    else:
        print(f"⚠️ Skipping {frame_name} due to missing data")

# === Save to CSV ===
with open(output_csv_path, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['frame', 'location', 'latitude', 'longitude', 'defects', 'count']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(data)

print(f"✅ Saved {len(data)} valid entries to {output_csv_path}")
# Out:
# 📝 Found 2357 GPS text files.
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00000.txt
# 📂 Frame: frame_00000.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: []
# ⚠️ Skipping frame_00000.jpg due to missing data
# 📂 Frame: frame_00001.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00002.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00003.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00004.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00005.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00006.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00007.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00008.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00009.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00010.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00011.jpg | Location: Unknown | Lat: 19.0957, Lon: 74.75153 | Labels: ['edge line']
# 📂 Frame: frame_00012.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line', 'edge line', 'crack']
# 📂 Frame: frame_00013.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line']
# 📂 Frame: frame_00014.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line']
# 📂 Frame: frame_00015.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00016.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line']
# 📂 Frame: frame_00017.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line']
# 📂 Frame: frame_00018.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line']
# 📂 Frame: frame_00019.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00020.txt
# 📂 Frame: frame_00020.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: []
# ⚠️ Skipping frame_00020.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00021.txt
# 📂 Frame: frame_00021.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: []
# ⚠️ Skipping frame_00021.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00022.txt
# 📂 Frame: frame_00022.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: []
# ⚠️ Skipping frame_00022.jpg due to missing data
# 📂 Frame: frame_00023.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line']
# 📂 Frame: frame_00024.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line']
# 📂 Frame: frame_00025.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line']
# 📂 Frame: frame_00026.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line']
# 📂 Frame: frame_00027.jpg | Location: Unknown | Lat: 19.095634, Lon: 74.75157 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00028.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line', 'edge line', 'edge line']
# 📂 Frame: frame_00029.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line', 'edge line', 'lane divider']
# 📂 Frame: frame_00030.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line', 'edge line']
# 📂 Frame: frame_00031.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'crack', 'lane divider', 'edge line', 'edge line']
# 📂 Frame: frame_00032.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line', 'edge line', 'lane divider']
# 📂 Frame: frame_00033.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'crack', 'edge line', 'edge line']
# 📂 Frame: frame_00034.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line', 'edge line']
# 📂 Frame: frame_00035.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00036.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00037.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00038.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00039.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00040.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00041.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00042.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line']
# 📂 Frame: frame_00043.jpg | Location: Unknown | Lat: 19.095564, Lon: 74.75161 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00044.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line', 'edge line']
# 📂 Frame: frame_00045.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line', 'edge line', 'edge line']
# 📂 Frame: frame_00046.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line', 'edge line', 'edge line']
# 📂 Frame: frame_00047.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line', 'edge line']
# 📂 Frame: frame_00048.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line', 'edge line', 'crack']
# 📂 Frame: frame_00049.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line', 'lane divider']
# 📂 Frame: frame_00050.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line', 'edge line']
# 📂 Frame: frame_00051.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line', 'edge line', 'crack']
# 📂 Frame: frame_00052.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'crack', 'edge line', 'edge line']
# 📂 Frame: frame_00053.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line']
# 📂 Frame: frame_00054.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line', 'edge line']
# 📂 Frame: frame_00055.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00056.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line']
# 📂 Frame: frame_00057.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line']
# 📂 Frame: frame_00058.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00059.jpg | Location: Unknown | Lat: 19.095484, Lon: 74.75165 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00060.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line']
# 📂 Frame: frame_00061.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00062.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00063.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line']
# 📂 Frame: frame_00064.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line']
# 📂 Frame: frame_00065.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00066.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line']
# 📂 Frame: frame_00067.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line']
# 📂 Frame: frame_00068.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line']
# 📂 Frame: frame_00069.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line']
# 📂 Frame: frame_00070.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line']
# 📂 Frame: frame_00071.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00072.txt
# 📂 Frame: frame_00072.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: []
# ⚠️ Skipping frame_00072.jpg due to missing data
# 📂 Frame: frame_00073.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00074.txt
# 📂 Frame: frame_00074.jpg | Location: Unknown | Lat: 19.095419, Lon: 74.75168 | Labels: []
# ⚠️ Skipping frame_00074.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00075.txt
# 📂 Frame: frame_00075.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00075.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00076.txt
# 📂 Frame: frame_00076.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00076.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00077.txt
# 📂 Frame: frame_00077.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00077.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00078.txt
# 📂 Frame: frame_00078.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00078.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00079.txt
# 📂 Frame: frame_00079.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00079.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00080.txt
# 📂 Frame: frame_00080.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00080.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00081.txt
# 📂 Frame: frame_00081.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00081.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00082.txt
# 📂 Frame: frame_00082.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00082.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00083.txt
# 📂 Frame: frame_00083.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00083.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00084.txt
# 📂 Frame: frame_00084.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00084.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00085.txt
# 📂 Frame: frame_00085.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00085.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00086.txt
# 📂 Frame: frame_00086.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00086.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00087.txt
# 📂 Frame: frame_00087.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00087.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00088.txt
# 📂 Frame: frame_00088.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00088.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00089.txt
# 📂 Frame: frame_00089.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00089.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00090.txt
# 📂 Frame: frame_00090.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00090.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00091.txt
# 📂 Frame: frame_00091.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00091.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00092.txt
# 📂 Frame: frame_00092.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00092.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00093.txt
# 📂 Frame: frame_00093.jpg | Location: Unknown | Lat: 19.09536, Lon: 74.7517 | Labels: []
# ⚠️ Skipping frame_00093.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00094.txt
# 📂 Frame: frame_00094.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00094.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00095.txt
# 📂 Frame: frame_00095.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00095.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00096.txt
# 📂 Frame: frame_00096.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00096.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00097.txt
# 📂 Frame: frame_00097.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00097.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00098.txt
# 📂 Frame: frame_00098.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00098.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00099.txt
# 📂 Frame: frame_00099.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00099.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00100.txt
# 📂 Frame: frame_00100.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00100.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00101.txt
# 📂 Frame: frame_00101.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00101.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00102.txt
# 📂 Frame: frame_00102.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00102.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00103.txt
# 📂 Frame: frame_00103.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00103.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00104.txt
# 📂 Frame: frame_00104.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00104.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00105.txt
# 📂 Frame: frame_00105.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00105.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00106.txt
# 📂 Frame: frame_00106.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00106.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00107.txt
# 📂 Frame: frame_00107.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00107.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00108.txt
# 📂 Frame: frame_00108.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00108.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00109.txt
# 📂 Frame: frame_00109.jpg | Location: Unknown | Lat: 19.095304, Lon: 74.75171 | Labels: []
# ⚠️ Skipping frame_00109.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00110.txt
# 📂 Frame: frame_00110.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00110.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00111.txt
# 📂 Frame: frame_00111.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00111.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00112.txt
# 📂 Frame: frame_00112.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00112.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00113.txt
# 📂 Frame: frame_00113.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00113.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00114.txt
# 📂 Frame: frame_00114.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00114.jpg due to missing data
# 📂 Frame: frame_00115.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00116.txt
# 📂 Frame: frame_00116.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00116.jpg due to missing data
# 📂 Frame: frame_00117.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00118.txt
# 📂 Frame: frame_00118.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00118.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00119.txt
# 📂 Frame: frame_00119.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00119.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00120.txt
# 📂 Frame: frame_00120.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00120.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00121.txt
# 📂 Frame: frame_00121.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00121.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00122.txt
# 📂 Frame: frame_00122.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00122.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00123.txt
# 📂 Frame: frame_00123.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00123.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00124.txt
# 📂 Frame: frame_00124.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00124.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00125.txt
# 📂 Frame: frame_00125.jpg | Location: Unknown | Lat: 19.095232, Lon: 74.75174 | Labels: []
# ⚠️ Skipping frame_00125.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00126.txt
# 📂 Frame: frame_00126.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00126.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00127.txt
# 📂 Frame: frame_00127.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00127.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00128.txt
# 📂 Frame: frame_00128.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00128.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00129.txt
# 📂 Frame: frame_00129.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00129.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00130.txt
# 📂 Frame: frame_00130.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00130.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00131.txt
# 📂 Frame: frame_00131.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00131.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00132.txt
# 📂 Frame: frame_00132.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00132.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00133.txt
# 📂 Frame: frame_00133.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00133.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00134.txt
# 📂 Frame: frame_00134.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00134.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00135.txt
# 📂 Frame: frame_00135.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00135.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00136.txt
# 📂 Frame: frame_00136.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00136.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00137.txt
# 📂 Frame: frame_00137.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00137.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00138.txt
# 📂 Frame: frame_00138.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00138.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00139.txt
# 📂 Frame: frame_00139.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00139.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00140.txt
# 📂 Frame: frame_00140.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00140.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00141.txt
# 📂 Frame: frame_00141.jpg | Location: Unknown | Lat: 19.095158, Lon: 74.751785 | Labels: []
# ⚠️ Skipping frame_00141.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00142.txt
# 📂 Frame: frame_00142.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: []
# ⚠️ Skipping frame_00142.jpg due to missing data
# 📂 Frame: frame_00143.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00144.txt
# 📂 Frame: frame_00144.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: []
# ⚠️ Skipping frame_00144.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00145.txt
# 📂 Frame: frame_00145.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: []
# ⚠️ Skipping frame_00145.jpg due to missing data
# 📂 Frame: frame_00146.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: ['edge line']
# 📂 Frame: frame_00147.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: ['edge line']
# 📂 Frame: frame_00148.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: ['edge line']
# 📂 Frame: frame_00149.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00150.txt
# 📂 Frame: frame_00150.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: []
# ⚠️ Skipping frame_00150.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00151.txt
# 📂 Frame: frame_00151.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: []
# ⚠️ Skipping frame_00151.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00152.txt
# 📂 Frame: frame_00152.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: []
# ⚠️ Skipping frame_00152.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00153.txt
# 📂 Frame: frame_00153.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: []
# ⚠️ Skipping frame_00153.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00154.txt
# 📂 Frame: frame_00154.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: []
# ⚠️ Skipping frame_00154.jpg due to missing data
# 📂 Frame: frame_00155.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: ['edge line']
# 📂 Frame: frame_00156.jpg | Location: Unknown | Lat: 19.095087, Lon: 74.751816 | Labels: ['edge line']
# 📂 Frame: frame_00157.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00158.txt
# 📂 Frame: frame_00158.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00158.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00159.txt
# 📂 Frame: frame_00159.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00159.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00160.txt
# 📂 Frame: frame_00160.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00160.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00161.txt
# 📂 Frame: frame_00161.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00161.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00162.txt
# 📂 Frame: frame_00162.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00162.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00163.txt
# 📂 Frame: frame_00163.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00163.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00164.txt
# 📂 Frame: frame_00164.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00164.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00165.txt
# 📂 Frame: frame_00165.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00165.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00166.txt
# 📂 Frame: frame_00166.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00166.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00167.txt
# 📂 Frame: frame_00167.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00167.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00168.txt
# 📂 Frame: frame_00168.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00168.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00169.txt
# 📂 Frame: frame_00169.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00169.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00170.txt
# 📂 Frame: frame_00170.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00170.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00171.txt
# 📂 Frame: frame_00171.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00171.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00172.txt
# 📂 Frame: frame_00172.jpg | Location: Unknown | Lat: 19.095024, Lon: 74.751854 | Labels: []
# ⚠️ Skipping frame_00172.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00173.txt
# 📂 Frame: frame_00173.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00173.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00174.txt
# 📂 Frame: frame_00174.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00174.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00175.txt
# 📂 Frame: frame_00175.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00175.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00176.txt
# 📂 Frame: frame_00176.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00176.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00177.txt
# 📂 Frame: frame_00177.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00177.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00178.txt
# 📂 Frame: frame_00178.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00178.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00179.txt
# 📂 Frame: frame_00179.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00179.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00180.txt
# 📂 Frame: frame_00180.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00180.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00181.txt
# 📂 Frame: frame_00181.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00181.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00182.txt
# 📂 Frame: frame_00182.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00182.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00183.txt
# 📂 Frame: frame_00183.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00183.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00184.txt
# 📂 Frame: frame_00184.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00184.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00185.txt
# 📂 Frame: frame_00185.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: []
# ⚠️ Skipping frame_00185.jpg due to missing data
# 📂 Frame: frame_00186.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: ['edge line']
# 📂 Frame: frame_00187.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: ['edge line']
# 📂 Frame: frame_00188.jpg | Location: Unknown | Lat: 19.094952, Lon: 74.7519 | Labels: ['edge line']
# 📂 Frame: frame_00189.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# 📂 Frame: frame_00190.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# 📂 Frame: frame_00191.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# 📂 Frame: frame_00192.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00193.txt
# 📂 Frame: frame_00193.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: []
# ⚠️ Skipping frame_00193.jpg due to missing data
# 📂 Frame: frame_00194.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# 📂 Frame: frame_00195.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00196.txt
# 📂 Frame: frame_00196.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: []
# ⚠️ Skipping frame_00196.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00197.txt
# 📂 Frame: frame_00197.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: []
# ⚠️ Skipping frame_00197.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00198.txt
# 📂 Frame: frame_00198.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: []
# ⚠️ Skipping frame_00198.jpg due to missing data
# 📂 Frame: frame_00199.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# 📂 Frame: frame_00200.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# 📂 Frame: frame_00201.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# 📂 Frame: frame_00202.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# 📂 Frame: frame_00203.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00204.txt
# 📂 Frame: frame_00204.jpg | Location: Unknown | Lat: 19.094872, Lon: 74.75192 | Labels: []
# ⚠️ Skipping frame_00204.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00205.txt
# 📂 Frame: frame_00205.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00205.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00206.txt
# 📂 Frame: frame_00206.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00206.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00207.txt
# 📂 Frame: frame_00207.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00207.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00208.txt
# 📂 Frame: frame_00208.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00208.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00209.txt
# 📂 Frame: frame_00209.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00209.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00210.txt
# 📂 Frame: frame_00210.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00210.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00211.txt
# 📂 Frame: frame_00211.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00211.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00212.txt
# 📂 Frame: frame_00212.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00212.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00213.txt
# 📂 Frame: frame_00213.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00213.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00214.txt
# 📂 Frame: frame_00214.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00214.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00215.txt
# 📂 Frame: frame_00215.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00215.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00216.txt
# 📂 Frame: frame_00216.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00216.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00217.txt
# 📂 Frame: frame_00217.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00217.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00218.txt
# 📂 Frame: frame_00218.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00218.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00219.txt
# 📂 Frame: frame_00219.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00219.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00220.txt
# 📂 Frame: frame_00220.jpg | Location: Unknown | Lat: 19.0948, Lon: 74.751976 | Labels: []
# ⚠️ Skipping frame_00220.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00221.txt
# 📂 Frame: frame_00221.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00221.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00222.txt
# 📂 Frame: frame_00222.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00222.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00223.txt
# 📂 Frame: frame_00223.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00223.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00224.txt
# 📂 Frame: frame_00224.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00224.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00225.txt
# 📂 Frame: frame_00225.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00225.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00226.txt
# 📂 Frame: frame_00226.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00226.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00227.txt
# 📂 Frame: frame_00227.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00227.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00228.txt
# 📂 Frame: frame_00228.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00228.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00229.txt
# 📂 Frame: frame_00229.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00229.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00230.txt
# 📂 Frame: frame_00230.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00230.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00231.txt
# 📂 Frame: frame_00231.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00231.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00232.txt
# 📂 Frame: frame_00232.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00232.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00233.txt
# 📂 Frame: frame_00233.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00233.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00234.txt
# 📂 Frame: frame_00234.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00234.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00235.txt
# 📂 Frame: frame_00235.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00235.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00236.txt
# 📂 Frame: frame_00236.jpg | Location: Unknown | Lat: 19.094728, Lon: 74.75202 | Labels: []
# ⚠️ Skipping frame_00236.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00237.txt
# 📂 Frame: frame_00237.jpg | Location: Unknown | Lat: None, Lon: None | Labels: []
# ⚠️ Skipping frame_00237.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00238.txt
# 📂 Frame: frame_00238.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: []
# ⚠️ Skipping frame_00238.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00239.txt
# 📂 Frame: frame_00239.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: []
# ⚠️ Skipping frame_00239.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00240.txt
# 📂 Frame: frame_00240.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: []
# ⚠️ Skipping frame_00240.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00241.txt
# 📂 Frame: frame_00241.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: []
# ⚠️ Skipping frame_00241.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00242.txt
# 📂 Frame: frame_00242.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: []
# ⚠️ Skipping frame_00242.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00243.txt
# 📂 Frame: frame_00243.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: []
# ⚠️ Skipping frame_00243.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00244.txt
# 📂 Frame: frame_00244.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: []
# ⚠️ Skipping frame_00244.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_00245.txt
# 📂 Frame: frame_00245.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: []
# ⚠️ Skipping frame_00245.jpg due to missing data
# 📂 Frame: frame_00246.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: ['edge line']
# 📂 Frame: frame_00247.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00248.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00249.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: ['edge line']
# 📂 Frame: frame_00250.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: ['edge line']
# 📂 Frame: frame_00251.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: ['edge line']
# 📂 Frame: frame_00252.jpg | Location: Unknown | Lat: 19.094671, Lon: 74.75205 | Labels: ['edge line']
# 📂 Frame: frame_00253.jpg | Location: Unknown | Lat: 19.094606, Lon: 74.75209 | Labels: ['edge line']
# 📂 Frame: frame_00254.jpg | Location: Unknown | Lat: 19.094606, Lon: 74.75209 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00255.jpg | Location: Unknown | Lat: 19.094606, Lon: 74.75209 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00256.jpg | Location: Unknown | Lat: 19.094606, Lon: 74.75209 | Labels: ['edge line']
# 📂 Frame: frame_00257.jpg | Location: Unknown | Lat: 19.094606, Lon: 74.75209 | Labels: ['edge line', 'edge line']
# 📂 Frame: frame_00258.jpg | Location: Unknown | Lat: 19.094606, Lon: 74.75209 | Labels: ['edge line']
# 📂 Frame: frame_00259.jpg | Location: Unknown | Lat: None, Lon: None | Labels: ['edge line', 'edge line']
# ⚠️ Skipping frame_00259.jpg due to missing data
# 📂 Frame: frame_00260.jpg | Location: Unknown | Lat: 19.094606, Lon: 74.75209 | Labels: ['edge line']
# ...
# ⚠️ Skipping frame_02270.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02271.txt
# 📂 Frame: frame_02271.jpg | Location: Unknown | Lat: 19.090956, Lon: 74.76486 | Labels: []
# ⚠️ Skipping frame_02271.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02272.txt
# 📂 Frame: frame_02272.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: []
# ⚠️ Skipping frame_02272.jpg due to missing data
# 📂 Frame: frame_02273.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: ['edge line', 'crack']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02274.txt
# 📂 Frame: frame_02274.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: []
# ⚠️ Skipping frame_02274.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02275.txt
# 📂 Frame: frame_02275.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: []
# ⚠️ Skipping frame_02275.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02276.txt
# 📂 Frame: frame_02276.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: []
# ⚠️ Skipping frame_02276.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02277.txt
# 📂 Frame: frame_02277.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: []
# ⚠️ Skipping frame_02277.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02278.txt
# 📂 Frame: frame_02278.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: []
# ⚠️ Skipping frame_02278.jpg due to missing data
# 📂 Frame: frame_02279.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: ['edge line']
# 📂 Frame: frame_02280.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: ['lane divider', 'crack']
# 📂 Frame: frame_02281.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: ['edge line', 'crack']
# 📂 Frame: frame_02282.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: ['crack', 'edge line']
# 📂 Frame: frame_02283.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: ['edge line', 'crack']
# 📂 Frame: frame_02284.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02285.txt
# 📂 Frame: frame_02285.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: []
# ⚠️ Skipping frame_02285.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02286.txt
# 📂 Frame: frame_02286.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: []
# ⚠️ Skipping frame_02286.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02287.txt
# 📂 Frame: frame_02287.jpg | Location: Unknown | Lat: 19.09097, Lon: 74.76478 | Labels: []
# ⚠️ Skipping frame_02287.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02288.txt
# 📂 Frame: frame_02288.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: []
# ⚠️ Skipping frame_02288.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02289.txt
# 📂 Frame: frame_02289.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: []
# ⚠️ Skipping frame_02289.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02290.txt
# 📂 Frame: frame_02290.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: []
# ⚠️ Skipping frame_02290.jpg due to missing data
# 📂 Frame: frame_02291.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02292.txt
# 📂 Frame: frame_02292.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: []
# ⚠️ Skipping frame_02292.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02293.txt
# 📂 Frame: frame_02293.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: []
# ⚠️ Skipping frame_02293.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02294.txt
# 📂 Frame: frame_02294.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: []
# ⚠️ Skipping frame_02294.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02295.txt
# 📂 Frame: frame_02295.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: []
# ⚠️ Skipping frame_02295.jpg due to missing data
# 📂 Frame: frame_02296.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: ['edge line']
# 📂 Frame: frame_02297.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: ['lane divider', 'edge line', 'edge line']
# 📂 Frame: frame_02298.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: ['crack']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02299.txt
# 📂 Frame: frame_02299.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: []
# ⚠️ Skipping frame_02299.jpg due to missing data
# 📂 Frame: frame_02300.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: ['edge line']
# 📂 Frame: frame_02301.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: ['edge line']
# 📂 Frame: frame_02302.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: ['crack']
# 📂 Frame: frame_02303.jpg | Location: Unknown | Lat: 19.090986, Lon: 74.7647 | Labels: ['edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02304.txt
# 📂 Frame: frame_02304.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: []
# ⚠️ Skipping frame_02304.jpg due to missing data
# 📂 Frame: frame_02305.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: ['lane divider']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02306.txt
# 📂 Frame: frame_02306.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: []
# ⚠️ Skipping frame_02306.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02307.txt
# 📂 Frame: frame_02307.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: []
# ⚠️ Skipping frame_02307.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02308.txt
# 📂 Frame: frame_02308.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: []
# ⚠️ Skipping frame_02308.jpg due to missing data
# 📂 Frame: frame_02309.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: ['lane divider']
# 📂 Frame: frame_02310.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: ['lane divider']
# 📂 Frame: frame_02311.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: ['crack', 'edge line']
# 📂 Frame: frame_02312.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: ['edge line', 'crack']
# 📂 Frame: frame_02313.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: ['edge line', 'crack']
# 📂 Frame: frame_02314.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: ['edge line', 'crack']
# 📂 Frame: frame_02315.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: ['crack']
# 📂 Frame: frame_02316.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: ['lane divider']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02317.txt
# 📂 Frame: frame_02317.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: []
# ⚠️ Skipping frame_02317.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02318.txt
# 📂 Frame: frame_02318.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: []
# ⚠️ Skipping frame_02318.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02319.txt
# 📂 Frame: frame_02319.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: []
# ⚠️ Skipping frame_02319.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02320.txt
# 📂 Frame: frame_02320.jpg | Location: Unknown | Lat: 19.091003, Lon: 74.76463 | Labels: []
# ⚠️ Skipping frame_02320.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02321.txt
# 📂 Frame: frame_02321.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: []
# ⚠️ Skipping frame_02321.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02322.txt
# 📂 Frame: frame_02322.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: []
# ⚠️ Skipping frame_02322.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02323.txt
# 📂 Frame: frame_02323.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: []
# ⚠️ Skipping frame_02323.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02324.txt
# 📂 Frame: frame_02324.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: []
# ⚠️ Skipping frame_02324.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02325.txt
# 📂 Frame: frame_02325.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: []
# ⚠️ Skipping frame_02325.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02326.txt
# 📂 Frame: frame_02326.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: []
# ⚠️ Skipping frame_02326.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02327.txt
# 📂 Frame: frame_02327.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: []
# ⚠️ Skipping frame_02327.jpg due to missing data
# 📂 Frame: frame_02328.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: ['lane divider']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02329.txt
# 📂 Frame: frame_02329.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: []
# ⚠️ Skipping frame_02329.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02330.txt
# 📂 Frame: frame_02330.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: []
# ⚠️ Skipping frame_02330.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02331.txt
# 📂 Frame: frame_02331.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: []
# ⚠️ Skipping frame_02331.jpg due to missing data
# 📂 Frame: frame_02332.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: ['crack']
# 📂 Frame: frame_02333.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: ['lane divider']
# 📂 Frame: frame_02334.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: ['lane divider']
# 📂 Frame: frame_02335.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: ['lane divider']
# 📂 Frame: frame_02336.jpg | Location: Unknown | Lat: 19.091028, Lon: 74.76458 | Labels: ['lane divider']
# 📂 Frame: frame_02337.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: ['lane divider']
# 📂 Frame: frame_02338.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: ['lane divider']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02339.txt
# 📂 Frame: frame_02339.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02339.jpg due to missing data
# 📂 Frame: frame_02340.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: ['edge line']
# 📂 Frame: frame_02341.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: ['edge line', 'edge line']
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02342.txt
# 📂 Frame: frame_02342.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02342.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02343.txt
# 📂 Frame: frame_02343.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02343.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02344.txt
# 📂 Frame: frame_02344.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02344.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02345.txt
# 📂 Frame: frame_02345.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02345.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02346.txt
# 📂 Frame: frame_02346.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02346.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02347.txt
# 📂 Frame: frame_02347.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02347.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02348.txt
# 📂 Frame: frame_02348.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02348.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02349.txt
# 📂 Frame: frame_02349.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02349.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02350.txt
# 📂 Frame: frame_02350.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02350.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02351.txt
# 📂 Frame: frame_02351.jpg | Location: Unknown | Lat: 19.091042, Lon: 74.7645 | Labels: []
# ⚠️ Skipping frame_02351.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02352.txt
# 📂 Frame: frame_02352.jpg | Location: Unknown | Lat: 19.091059, Lon: 74.76443 | Labels: []
# ⚠️ Skipping frame_02352.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02353.txt
# 📂 Frame: frame_02353.jpg | Location: Unknown | Lat: 19.091059, Lon: 74.76443 | Labels: []
# ⚠️ Skipping frame_02353.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02354.txt
# 📂 Frame: frame_02354.jpg | Location: Unknown | Lat: 19.091059, Lon: 74.76443 | Labels: []
# ⚠️ Skipping frame_02354.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02355.txt
# 📂 Frame: frame_02355.jpg | Location: Unknown | Lat: 19.091059, Lon: 74.76443 | Labels: []
# ⚠️ Skipping frame_02355.jpg due to missing data
# ⚠️ Label file not found: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\frame_02356.txt
# 📂 Frame: frame_02356.jpg | Location: Unknown | Lat: 19.091059, Lon: 74.76443 | Labels: []
# ⚠️ Skipping frame_02356.jpg due to missing data
# ✅ Saved 885 valid entries to G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\defect_summary.csv

# %%
# as we can see in above csv file only latitude and longitude is extracted
# this script extract the location from given co-ordinates
# !pip install geopy



import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# --- Step 3: Load your data ---
# This line assumes your CSV file is named 'defect_summary_filled.csv' and is uploaded to Colab.
try:
    df = pd.read_csv(r"G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\defect_summary.csv")
    print("DataFrame loaded successfully.")
    print("First 5 rows of the loaded DataFrame:")
    print(df.head())
except FileNotFoundError:
    print("Error: 'defect_summary_filled.csv' not found.")
    print("Please ensure the file is uploaded to your Colab session storage (Step 2).")
    # If the file is not found, the rest of the script cannot proceed.
    exit() # Exit the script if the file isn't found

# --- Step 4: Initialize the geocoder ---
# We are using Nominatim, which is a geocoding service based on OpenStreetMap data.
# IMPORTANT: Provide a unique 'user_agent' string (e.g., your app name or email).
# This is required by Nominatim's usage policy to identify your application.
geolocator = Nominatim(user_agent="my_colab_geocoding_project")

# --- Step 5: Implement a rate limiter to avoid hitting API limits ---
# Geocoding services have usage policies and often rate limits (e.g., 1 request per second).
# The RateLimiter will automatically pause requests to ensure compliance.
# This is CRUCIAL to prevent your IP from being temporarily blocked by the service.
geocode = RateLimiter(geolocator.reverse, min_delay_seconds=1)

# --- Step 6: Define a helper function to get location for a single row ---
def get_location_from_coords(row):
    # Only attempt geocoding if both latitude and longitude are valid numbers (not NaN)
    if pd.notna(row['latitude']) and pd.notna(row['longitude']):
        try:
            # Create a tuple of coordinates (latitude, longitude)
            coords = (row['latitude'], row['longitude'])
            # Call the reverse geocoding service
            location = geocode(coords)
            # If a location is found, return its full address, otherwise return None
            return location.address if location else None
        except Exception as e:
            # Print any errors encountered during the geocoding request for debugging
            print(f"Error geocoding coordinates ({row['latitude']}, {row['longitude']}): {e}")
            return None
    return None # Return None if coordinates are missing or invalid

# --- Step 7: Prepare the 'location' column for filling ---
# Ensure that any existing 'Unknown' or 'NA' string values in the 'location' column
# are converted to actual pandas NaN (Not a Number) values. This allows `pd.isna()`
# to correctly identify which cells need to be filled.
df['location'] = df['location'].replace(['Unknown', 'NA'], pd.NA)

# --- Step 8: Apply the geocoding function to fill missing locations ---
print("\nStarting geocoding process. This might take a while depending on:")
print("  - The number of missing locations.")
print("  - The rate limit of the geocoding API (e.g., 1 second per request).")

# Identify rows where the 'location' column is currently missing (NaN)
missing_location_mask = df['location'].isna()

# Apply the 'get_location_from_coords' function ONLY to the rows
# where the 'location' is missing. This optimizes the process.
df.loc[missing_location_mask, 'location'] = df[missing_location_mask].apply(get_location_from_coords, axis=1)

print("\nGeocoding process complete.")

# --- Step 9: Display the updated DataFrame and check for any remaining missing values ---
print("\nDataFrame after attempting to fill missing locations:")
print(df.head())

print("\nNumber of missing values in 'location' column after geocoding attempt:")
print(df['location'].isna().sum())

# --- Step 10: (Optional) Save the updated DataFrame to a new CSV file ---
# You can download this new CSV file from Colab's file browser after it's created.
#df.to_csv('defect_summary_geocoded_updated.csv', index=False)
# print("\nUpdated DataFrame saved to 'defect_summary_geocoded_updated.csv'")
# Out:
# Requirement already satisfied: geopy in c:\users\hp\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\hp\anaconda3\lib\site-packages (from geopy) (2.0)
# DataFrame loaded successfully.
# First 5 rows of the loaded DataFrame:
#              frame location  latitude  longitude    defects  count
# 0  frame_00001.jpg  Unknown   19.0957   74.75153  edge line      1
# 1  frame_00002.jpg  Unknown   19.0957   74.75153  edge line      1
# 2  frame_00003.jpg  Unknown   19.0957   74.75153  edge line      1
# 3  frame_00004.jpg  Unknown   19.0957   74.75153  edge line      1
# 4  frame_00005.jpg  Unknown   19.0957   74.75153  edge line      1
#
# Starting geocoding process. This might take a while depending on:
#   - The number of missing locations.
#   - The rate limit of the geocoding API (e.g., 1 second per request).
# C:\Users\HP\anaconda3\Lib\site-packages\geopy\point.py:472: UserWarning: Latitude normalization has been prohibited in the newer versions of geopy, because the normalized value happened to be on a different pole, which is probably not what was meant. If you pass coordinates as positional args, please make sure that the order is (latitude, longitude) or (y, x) in Cartesian terms.
#   return cls(*args)
# Error geocoding coordinates (19092632.0, 74.76649): Must be a coordinate pair or Point
#
# Geocoding process complete.
#
# DataFrame after attempting to fill missing locations:
#              frame                                           location  \
# 0  frame_00001.jpg  Foi, अहिल्यानगर, Ahmednagar, Maharashtra, 4140...
# 1  frame_00002.jpg  Foi, अहिल्यानगर, Ahmednagar, Maharashtra, 4140...
# 2  frame_00003.jpg  Foi, अहिल्यानगर, Ahmednagar, Maharashtra, 4140...
# 3  frame_00004.jpg  Foi, अहिल्यानगर, Ahmednagar, Maharashtra, 4140...
# 4  frame_00005.jpg  Foi, अहिल्यानगर, Ahmednagar, Maharashtra, 4140...
#
#    latitude  longitude    defects  count
# 0   19.0957   74.75153  edge line      1
# 1   19.0957   74.75153  edge line      1
# 2   19.0957   74.75153  edge line      1
# 3   19.0957   74.75153  edge line      1
# 4   19.0957   74.75153  edge line      1
#
# Number of missing values in 'location' column after geocoding attempt:
# 1

# %%
# You can download this new CSV file from Colab's file browser after it's created.
df.to_csv('G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\defect_summary_geocoded_updated.csv', index=False)
print("\nUpdated DataFrame saved to 'defect_summary_geocoded_updated.csv'")
# Out:
# Updated DataFrame saved to 'defect_summary_geocoded_updated.csv'
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\HP\AppData\Local\Temp\ipykernel_6292\1724353647.py:2: SyntaxWarning: invalid escape sequence '\G'
#   df.to_csv('G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\defect_summary_geocoded_updated.csv', index=False)

# %%
#there is text written in marathi but as it only refers to ahmednagar itself we removed it using this script

import pandas as pd

# Load the CSV (without 'errors' argument)
input_file = r'G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\defect_summary_geocoded_updated.csv'  # Update path if needed
df = pd.read_csv(input_file, encoding='utf-8')

# Function to clean location text by removing non-ASCII parts
def remove_garbled_marathi(text):
    if isinstance(text, str):
        # Keep only parts that contain mostly ASCII characters
        parts = text.split(",")
        cleaned_parts = [part.strip() for part in parts if all(ord(c) < 128 for c in part)]
        return ", ".join(cleaned_parts)
    return text

# Apply the function to the 'location' column
df['location'] = df['location'].apply(remove_garbled_marathi)

# Save the cleaned DataFrame
output_file = r"G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\summary_cleaned.csv"
df.to_csv(output_file, index=False, encoding='utf-8')

print(f"✅ Cleaned CSV saved to: {output_file}")
# Out:
# ✅ Cleaned CSV saved to: G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\summary_cleaned.csv

# %%
import pandas as pd

# Load your CSV file
csv_path = r"G:\Group_2_Road_Defect_Analysis\Prediction_Output\labels\summary_cleaned.csv"
df = pd.read_csv(csv_path)

# Remove "Foi, " if it appears at the start of the location
df['location'] = df['location'].str.replace(r'^Foi,\s*', '', regex=True)

# Save the cleaned CSV
df.to_csv(csv_path, index=False)
print("✅ Removed 'Foi,' from location column and saved updated CSV.")
# Out:
# ✅ Removed 'Foi,' from location column and saved updated CSV.
